# %%
import pandas as pd
import numpy as np

# %%
childhood_violent_crime_to_load = "../Children-in-households-with-violent-crime_2014_0731_1400.csv"

childhood_violent_crime = pd.read_csv(childhood_violent_crime_to_load)

childhood_violent_crime.head()
# Out:
#   Characteristic  Sex Race/ethnicity Type of violent crime Footnote  Year  \
# 0          Total  NaN            NaN                   NaN      NaN  2000
# 1          Total  NaN            NaN                   NaN      NaN  2001
# 2          Total  NaN            NaN                   NaN      NaN  2002
# 3          Total  NaN            NaN                   NaN      NaN  2003
# 4          Total  NaN            NaN                   NaN      NaN  2004
#
#    Percentage  Standard Error on Percentage Note on Percent      Count  \
# 0         7.1                           0.5                  5019760.0
# 1         6.2                           0.4                  4420020.0
# 2         5.6                           0.4                  3998780.0
# 3         5.8                           0.4                  4203810.0
# 4         5.0                           0.3                  3644200.0
#
#    Standard Error on Count Note on Count
# 0                 362090.9
# 1                 297104.6
# 2                 335455.7
# 3                 318712.6
# 4                 251933.3

# %%
# Remove grand total, total for males, and total for females from this analysis
childhood_violent_crime_cleaned = childhood_violent_crime.dropna(subset = ["Sex", "Race/ethnicity"])
childhood_violent_crime_cleaned
# Out:
#                                         Characteristic     Sex  \
# 117   Total - Male, White, non-Hispanic, Violent crime    Male
# 118   Total - Male, White, non-Hispanic, Violent crime    Male
# 119   Total - Male, White, non-Hispanic, Violent crime    Male
# 120   Total - Male, White, non-Hispanic, Violent crime    Male
# 121   Total - Male, White, non-Hispanic, Violent crime    Male
# ..                                                 ...     ...
# 788  Total - Female, Two or more races, non-Hispani...  Female
# 789  Total - Female, Two or more races, non-Hispani...  Female
# 790  Total - Female, Two or more races, non-Hispani...  Female
# 791  Total - Female, Two or more races, non-Hispani...  Female
# 792  Total - Female, Two or more races, non-Hispani...  Female
#
#                       Race/ethnicity Type of violent crime Footnote  Year  \
# 117              White, non-Hispanic         Violent crime      NaN  2000
# 118              White, non-Hispanic         Violent crime      NaN  2001
# 119              White, non-Hispanic         Violent crime      NaN  2002
# 120              White, non-Hispanic         Violent crime      NaN  2003
# 121              White, non-Hispanic         Violent crime      NaN  2004
# ..                               ...                   ...      ...   ...
# 788  Two or more races, non-Hispanic        Simple assault      NaN  2008
# 789  Two or more races, non-Hispanic        Simple assault      NaN  2009
# 790  Two or more races, non-Hispanic        Simple assault      NaN  2010
# 791  Two or more races, non-Hispanic        Simple assault      NaN  2011
# 792  Two or more races, non-Hispanic        Simple assault      NaN  2012
#
#      Percentage  Standard Error on Percentage  \
# 117         6.7                           0.6
# 118         5.2                           0.5
# 119         4.3                           0.5
# 120         4.6                           0.5
# 121         5.0                           0.5
# ..          ...                           ...
# 788        12.6                           4.2
# 789        14.1                           4.6
# 790         2.7                           1.6
# 791         7.0                           2.6
# 792         9.8                           3.4
#
#                                        Note on Percent      Count  \
# 117                                                     1868830.0
# 118                                                     1410800.0
# 119                                                     1121580.0
# 120                                                     1198070.0
# 121                                                     1241850.0
# ..                                                 ...        ...
# 788  Interpret with caution. Estimate based on 10 o...    54290.0
# 789  Interpret with caution. Estimate based on 10 o...    51370.0
# 790  Interpret with caution. Estimate based on 10 o...     9570.0
# 791  Interpret with caution. Estimate based on 10 o...    26070.0
# 792  Interpret with caution. Estimate based on 10 o...    38530.0
#
#      Standard Error on Count  \
# 117                 182685.1
# 118                 136673.6
# 119                 137437.1
# 120                 134083.0
# 121                 122063.9
# ..                       ...
# 788                  20506.5
# 789                  19338.4
# 790                   5901.6
# 791                  10677.3
# 792                  14618.0
#
#                                          Note on Count
# 117
# 118
# 119
# 120
# 121
# ..                                                 ...
# 788  Interpret with caution. Estimate based on 10 o...
# 789  Interpret with caution. Estimate based on 10 o...
# 790  Interpret with caution. Estimate based on 10 o...
# 791  Interpret with caution. Estimate based on 10 o...
# 792  Interpret with caution. Estimate based on 10 o...
#
# [468 rows x 12 columns]
